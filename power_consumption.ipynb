# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\SAMARTH P SHET'

# %%
data = pd.read_csv(r"C:\Users\SAMARTH P SHET\2015-building-energy-benchmarking.csv")
data.head()
data1 = pd.read_csv(r"C:\Users\SAMARTH P SHET\2016-building-energy-benchmarking.csv")
data1.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# 1                    0659000220  ...      9.504252e+05         3242851.0
# 2                    0659000475  ...      1.451544e+07        49526664.0
# 3                    0659000640  ...      8.115253e+05         2768924.0
# 4                    0659000970  ...      1.573449e+06         5368607.0
#
#    NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  Comments  \
# 0         12764.52930         1276453.0        False       NaN
# 1         51450.81641         5145082.0        False       NaN
# 2         14938.00000         1493800.0        False       NaN
# 3         18112.13086         1811213.0        False       NaN
# 4         88039.98438         8803998.0        False       NaN
#
#    ComplianceStatus  Outlier  TotalGHGEmissions  GHGEmissionsIntensity
# 0         Compliant      NaN             249.98                   2.83
# 1         Compliant      NaN             295.86                   2.86
# 2         Compliant      NaN            2089.28                   2.19
# 3         Compliant      NaN             286.43                   4.67
# 4         Compliant      NaN             505.01                   2.88
#
# [5 rows x 46 columns]

# %%
 data.drop(['DataYear','PropertyName', 'TaxParcelIdentificationNumber', 
       'CouncilDistrictCode','DefaultData', 'Comment', 'ComplianceStatus','ListOfAllPropertyUseTypes','LargestPropertyUseType','LargestPropertyUseTypeGFA','SecondLargestPropertyUseType',
         'SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA', 
       '2010 Census Tracts','Seattle Police Department Micro Community Policing Plan Areas',
       'City Council Districts','Neighborhood', 'YearsENERGYSTARCertified','SPD Beats', 'Zip Codes','Outlier'],axis=1,inplace=True)

data.head()
# Out:
#    OSEBuildingID    BuildingType PrimaryPropertyType  \
# 0              1  NonResidential               Hotel
# 1              2  NonResidential               Hotel
# 2              3  NonResidential               Hotel
# 3              5  NonResidential               Hotel
# 4              8  NonResidential               Hotel
#
#                                             Location  YearBuilt  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...       1927
# 1  {'latitude': '47.61310583', 'longitude': '-122...       1996
# 2  {'latitude': '47.61334897', 'longitude': '-122...       1969
# 3  {'latitude': '47.61421585', 'longitude': '-122...       1926
# 4  {'latitude': '47.6137544', 'longitude': '-122....       1980
#
#    NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                  1            12.0             88434                   0
# 1                  1            11.0            103566               15064
# 2                  1            41.0            961990                   0
# 3                  1            10.0             61320                   0
# 4                  1            18.0            119890               12460
#
#    PropertyGFABuilding(s)  ...  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# 0                   88434  ...            6981428.0              7097539.0
# 1                   88502  ...            8354235.0              8765788.0
# 2                  961990  ...           73130656.0             75506272.0
# 3                   61320  ...           28229320.0             28363444.0
# 4                  107430  ...           14829099.0             15078243.0
#
#    SteamUse(kBtu)  Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 0       2023032.0         1080307.0          3686160.0             12724.0
# 1             0.0         1144563.0          3905411.0             44490.0
# 2      19660404.0        14583930.0         49762435.0             37099.0
# 3      23458518.0          811521.0          2769023.0             20019.0
# 4             0.0         1777841.0          6066245.0             87631.0
#
#    NaturalGas(kBtu)  OtherFuelUse(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 0         1272388.0                 0.0                        249.43
# 1         4448985.0                 0.0                        263.51
# 2         3709900.0                 0.0                       2061.48
# 3         2001894.0                 0.0                       1936.34
# 4         8763105.0                 0.0                        507.70
#
#    GHGEmissionsIntensity(kgCO2e/ft2)
# 0                               2.64
# 1                               2.38
# 2                               1.92
# 3                              31.38
# 4                               4.02
#
# [5 rows x 25 columns]

# %%
data1.drop(['DataYear','PropertyName', 'TaxParcelIdentificationNumber', 
       'CouncilDistrictCode','DefaultData','ListOfAllPropertyUseTypes','LargestPropertyUseType','LargestPropertyUseTypeGFA','SecondLargestPropertyUseType',
         'SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA','Comments'  
       ,'Neighborhood', 'YearsENERGYSTARCertified', 'ZipCode','Address','City','State','Outlier'],axis=1,inplace=True)

data1.head()
# Out:
#    OSEBuildingID    BuildingType PrimaryPropertyType  Latitude  Longitude  \
# 0              1  NonResidential               Hotel  47.61220 -122.33799
# 1              2  NonResidential               Hotel  47.61317 -122.33393
# 2              3  NonResidential               Hotel  47.61393 -122.33810
# 3              5  NonResidential               Hotel  47.61412 -122.33664
# 4              8  NonResidential               Hotel  47.61375 -122.34047
#
#    YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0       1927                1.0              12             88434
# 1       1996                1.0              11            103566
# 2       1969                1.0              41            956110
# 3       1926                1.0              10             61320
# 4       1980                1.0              18            175580
#
#    PropertyGFAParking  ...  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# 0                   0  ...            7226362.5              7456910.0
# 1               15064  ...            8387933.0              8664479.0
# 2              196718  ...           72587024.0             73937112.0
# 3                   0  ...            6794584.0              6946800.5
# 4               62000  ...           14172606.0             14656503.0
#
#    SteamUse(kBtu)  Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 0      2003882.00      1.156514e+06          3946027.0         12764.52930
# 1            0.00      9.504252e+05          3242851.0         51450.81641
# 2     21566554.00      1.451544e+07         49526664.0         14938.00000
# 3      2214446.25      8.115253e+05          2768924.0         18112.13086
# 4            0.00      1.573449e+06          5368607.0         88039.98438
#
#    NaturalGas(kBtu)  ComplianceStatus  TotalGHGEmissions  \
# 0         1276453.0         Compliant             249.98
# 1         5145082.0         Compliant             295.86
# 2         1493800.0         Compliant            2089.28
# 3         1811213.0         Compliant             286.43
# 4         8803998.0         Compliant             505.01
#
#    GHGEmissionsIntensity
# 0                   2.83
# 1                   2.86
# 2                   2.19
# 3                   4.67
# 4                   2.88
#
# [5 rows x 26 columns]

# %%
data.set_index(["OSEBuildingID"],inplace=True)
data1.set_index(["OSEBuildingID"],inplace=True)

# %%
data.isnull().sum()
# Out:
# BuildingType                           0
# PrimaryPropertyType                    0
# Location                               0
# YearBuilt                              0
# NumberofBuildings                      0
# NumberofFloors                         8
# PropertyGFATotal                       0
# PropertyGFAParking                     0
# PropertyGFABuilding(s)                 0
# ENERGYSTARScore                      780
# SiteEUI(kBtu/sf)                      10
# SiteEUIWN(kBtu/sf)                    10
# SourceEUI(kBtu/sf)                    10
# SourceEUIWN(kBtu/sf)                  10
# SiteEnergyUse(kBtu)                   10
# SiteEnergyUseWN(kBtu)                 10
# SteamUse(kBtu)                        10
# Electricity(kWh)                      10
# Electricity(kBtu)                     10
# NaturalGas(therms)                    10
# NaturalGas(kBtu)                      10
# OtherFuelUse(kBtu)                    10
# GHGEmissions(MetricTonsCO2e)          10
# GHGEmissionsIntensity(kgCO2e/ft2)     10
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# BuildingType                0
# PrimaryPropertyType         0
# Latitude                    0
# Longitude                   0
# YearBuilt                   0
# NumberofBuildings           8
# NumberofFloors              0
# PropertyGFATotal            0
# PropertyGFAParking          0
# PropertyGFABuilding(s)      0
# ENERGYSTARScore           843
# SiteEUI(kBtu/sf)            7
# SiteEUIWN(kBtu/sf)          6
# SourceEUI(kBtu/sf)          9
# SourceEUIWN(kBtu/sf)        9
# SiteEnergyUse(kBtu)         5
# SiteEnergyUseWN(kBtu)       6
# SteamUse(kBtu)              9
# Electricity(kWh)            9
# Electricity(kBtu)           9
# NaturalGas(therms)          9
# NaturalGas(kBtu)            9
# ComplianceStatus            0
# TotalGHGEmissions           9
# GHGEmissionsIntensity       9
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3340 entries, 1 to 50059
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   BuildingType                       3340 non-null   object
#  1   PrimaryPropertyType                3340 non-null   object
#  2   Location                           3340 non-null   object
#  3   YearBuilt                          3340 non-null   int64
#  4   NumberofBuildings                  3340 non-null   int64
#  5   NumberofFloors                     3332 non-null   float64
#  6   PropertyGFATotal                   3340 non-null   int64
#  7   PropertyGFAParking                 3340 non-null   int64
#  8   PropertyGFABuilding(s)             3340 non-null   int64
#  9   ENERGYSTARScore                    2560 non-null   float64
#  10  SiteEUI(kBtu/sf)                   3330 non-null   float64
#  11  SiteEUIWN(kBtu/sf)                 3330 non-null   float64
#  12  SourceEUI(kBtu/sf)                 3330 non-null   float64
#  13  SourceEUIWN(kBtu/sf)               3330 non-null   float64
#  14  SiteEnergyUse(kBtu)                3330 non-null   float64
#  15  SiteEnergyUseWN(kBtu)              3330 non-null   float64
#  16  SteamUse(kBtu)                     3330 non-null   float64
#  17  Electricity(kWh)                   3330 non-null   float64
#  18  Electricity(kBtu)                  3330 non-null   float64
#  19  NaturalGas(therms)                 3330 non-null   float64
#  20  NaturalGas(kBtu)                   3330 non-null   float64
#  21  OtherFuelUse(kBtu)                 3330 non-null   float64
#  22  GHGEmissions(MetricTonsCO2e)       3330 non-null   float64
#  23  GHGEmissionsIntensity(kgCO2e/ft2)  3330 non-null   float64
# dtypes: float64(16), int64(5), object(3)
# memory usage: 652.3+ KB

# %%
data.dropna(inplace=True)
data1.dropna(inplace=True)

# %%
print(data.shape)
print(data1.shape)
# Out:
# (2557, 24)
# (2532, 25)

# %%
data1.rename(columns={"TotalGHGEmissions": "GHGEmissions(MetricTonsCO2e)", "GHGEmissionsIntensity": "GHGEmissionsIntensity(kgCO2e/ft2)"},inplace=True)

# %%
data.corr()
# Out:
#                                    YearBuilt  NumberofBuildings  \
# YearBuilt                           1.000000          -0.000889
# NumberofBuildings                  -0.000889           1.000000
# NumberofFloors                      0.135709          -0.015668
# PropertyGFATotal                    0.191093           0.062246
# PropertyGFAParking                  0.251526          -0.002940
# PropertyGFABuilding(s)              0.154600           0.073625
# ENERGYSTARScore                     0.011323          -0.023750
# SiteEUI(kBtu/sf)                   -0.011379          -0.002434
# SiteEUIWN(kBtu/sf)                 -0.035628          -0.004276
# SourceEUI(kBtu/sf)                  0.067736           0.002781
# SourceEUIWN(kBtu/sf)                0.057920           0.001283
# SiteEnergyUse(kBtu)                 0.074859           0.040774
# SiteEnergyUseWN(kBtu)               0.070554           0.038661
# SteamUse(kBtu)                     -0.000701          -0.002732
# Electricity(kWh)                    0.101451           0.062270
# Electricity(kBtu)                   0.101451           0.062270
# NaturalGas(therms)                  0.013552          -0.007307
# NaturalGas(kBtu)                    0.013553          -0.007307
# OtherFuelUse(kBtu)                 -0.023860          -0.001279
# GHGEmissions(MetricTonsCO2e)        0.022794           0.004351
# GHGEmissionsIntensity(kgCO2e/ft2)  -0.194266          -0.012798
#
#                                    NumberofFloors  PropertyGFATotal  \
# YearBuilt                                0.135709          0.191093
# NumberofBuildings                       -0.015668          0.062246
# NumberofFloors                           1.000000          0.672101
# PropertyGFATotal                         0.672101          1.000000
# PropertyGFAParking                       0.507653          0.691813
# PropertyGFABuilding(s)                   0.647100          0.980212
# ENERGYSTARScore                          0.012372          0.056595
# SiteEUI(kBtu/sf)                         0.053606          0.128175
# SiteEUIWN(kBtu/sf)                       0.037103          0.102080
# SourceEUI(kBtu/sf)                       0.075039          0.147273
# SourceEUIWN(kBtu/sf)                     0.063288          0.124474
# SiteEnergyUse(kBtu)                      0.383331          0.664706
# SiteEnergyUseWN(kBtu)                    0.367165          0.641464
# SteamUse(kBtu)                           0.097075          0.305872
# Electricity(kWh)                         0.453377          0.690124
# Electricity(kBtu)                        0.453377          0.690124
# NaturalGas(therms)                       0.129906          0.325736
# NaturalGas(kBtu)                         0.129906          0.325736
# OtherFuelUse(kBtu)                       0.080306          0.123384
# GHGEmissions(MetricTonsCO2e)             0.207579          0.492319
# GHGEmissionsIntensity(kgCO2e/ft2)       -0.005582          0.038034
#
#                                    PropertyGFAParking  PropertyGFABuilding(s)  \
# YearBuilt                                    0.251526                0.154600
# NumberofBuildings                           -0.002940                0.073625
# NumberofFloors                               0.507653                0.647100
# PropertyGFATotal                             0.691813                0.980212
# PropertyGFAParking                           1.000000                0.535189
# PropertyGFABuilding(s)                       0.535189                1.000000
# ENERGYSTARScore                              0.079534                0.044406
# SiteEUI(kBtu/sf)                             0.082767                0.127258
# SiteEUIWN(kBtu/sf)                           0.063051                0.102136
# SourceEUI(kBtu/sf)                           0.126660                0.137567
# SourceEUIWN(kBtu/sf)                         0.112996                0.114641
# SiteEnergyUse(kBtu)                          0.293040                0.697283
# SiteEnergyUseWN(kBtu)                        0.278250                0.674147
# SteamUse(kBtu)                               0.018835                0.352665
# Electricity(kWh)                             0.370977                0.705652
# Electricity(kBtu)                            0.370977                0.705652
# NaturalGas(therms)                           0.093083                0.355549
# NaturalGas(kBtu)                             0.093082                0.355549
# OtherFuelUse(kBtu)                           0.063256                0.127002
# GHGEmissions(MetricTonsCO2e)                 0.120687                0.542862
# GHGEmissionsIntensity(kgCO2e/ft2)           -0.070136                0.063721
#
#                                    ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# YearBuilt                                 0.011323         -0.011379
# NumberofBuildings                        -0.023750         -0.002434
# NumberofFloors                            0.012372          0.053606
# PropertyGFATotal                          0.056595          0.128175
# PropertyGFAParking                        0.079534          0.082767
# PropertyGFABuilding(s)                    0.044406          0.127258
# ENERGYSTARScore                           1.000000         -0.393877
# SiteEUI(kBtu/sf)                         -0.393877          1.000000
# SiteEUIWN(kBtu/sf)                       -0.403069          0.994512
# SourceEUI(kBtu/sf)                       -0.374965          0.948973
# SourceEUIWN(kBtu/sf)                     -0.386483          0.950732
# SiteEnergyUse(kBtu)                      -0.090264          0.462292
# SiteEnergyUseWN(kBtu)                    -0.096584          0.464771
# SteamUse(kBtu)                           -0.041999          0.154184
# Electricity(kWh)                         -0.064924          0.460232
# Electricity(kBtu)                        -0.064924          0.460232
# NaturalGas(therms)                       -0.112974          0.329646
# NaturalGas(kBtu)                         -0.112974          0.329646
# OtherFuelUse(kBtu)                        0.023550         -0.000470
# GHGEmissions(MetricTonsCO2e)             -0.097878          0.351278
# GHGEmissionsIntensity(kgCO2e/ft2)        -0.261099          0.667590
#
#                                    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  \
# YearBuilt                                   -0.035628            0.067736
# NumberofBuildings                           -0.004276            0.002781
# NumberofFloors                               0.037103            0.075039
# PropertyGFATotal                             0.102080            0.147273
# PropertyGFAParking                           0.063051            0.126660
# PropertyGFABuilding(s)                       0.102136            0.137567
# ENERGYSTARScore                             -0.403069           -0.374965
# SiteEUI(kBtu/sf)                             0.994512            0.948973
# SiteEUIWN(kBtu/sf)                           1.000000            0.926365
# SourceEUI(kBtu/sf)                           0.926365            1.000000
# SourceEUIWN(kBtu/sf)                         0.935557            0.996390
# SiteEnergyUse(kBtu)                          0.441223            0.463308
# SiteEnergyUseWN(kBtu)                        0.450189            0.460837
# SteamUse(kBtu)                               0.149265            0.117877
# Electricity(kWh)                             0.430456            0.523104
# Electricity(kBtu)                            0.430456            0.523104
# NaturalGas(therms)                           0.333866            0.217131
# NaturalGas(kBtu)                             0.333866            0.217131
# OtherFuelUse(kBtu)                          -0.016209            0.004664
# GHGEmissions(MetricTonsCO2e)                 0.345217            0.278173
# GHGEmissionsIntensity(kgCO2e/ft2)            0.698495            0.417951
#
#                                    ...  SiteEnergyUse(kBtu)  \
# YearBuilt                          ...             0.074859
# NumberofBuildings                  ...             0.040774
# NumberofFloors                     ...             0.383331
# PropertyGFATotal                   ...             0.664706
# PropertyGFAParking                 ...             0.293040
# PropertyGFABuilding(s)             ...             0.697283
# ENERGYSTARScore                    ...            -0.090264
# SiteEUI(kBtu/sf)                   ...             0.462292
# SiteEUIWN(kBtu/sf)                 ...             0.441223
# SourceEUI(kBtu/sf)                 ...             0.463308
# SourceEUIWN(kBtu/sf)               ...             0.450822
# SiteEnergyUse(kBtu)                ...             1.000000
# SiteEnergyUseWN(kBtu)              ...             0.992507
# SteamUse(kBtu)                     ...             0.622127
# Electricity(kWh)                   ...             0.938876
# Electricity(kBtu)                  ...             0.938876
# NaturalGas(therms)                 ...             0.577328
# NaturalGas(kBtu)                   ...             0.577328
# OtherFuelUse(kBtu)                 ...             0.048241
# GHGEmissions(MetricTonsCO2e)       ...             0.882793
# GHGEmissionsIntensity(kgCO2e/ft2)  ...             0.303591
#
#                                    SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# YearBuilt                                       0.070554       -0.000701
# NumberofBuildings                               0.038661       -0.002732
# NumberofFloors                                  0.367165        0.097075
# PropertyGFATotal                                0.641464        0.305872
# PropertyGFAParking                              0.278250        0.018835
# PropertyGFABuilding(s)                          0.674147        0.352665
# ENERGYSTARScore                                -0.096584       -0.041999
# SiteEUI(kBtu/sf)                                0.464771        0.154184
# SiteEUIWN(kBtu/sf)                              0.450189        0.149265
# SourceEUI(kBtu/sf)                              0.460837        0.117877
# SourceEUIWN(kBtu/sf)                            0.455179        0.114826
# SiteEnergyUse(kBtu)                             0.992507        0.622127
# SiteEnergyUseWN(kBtu)                           1.000000        0.625624
# SteamUse(kBtu)                                  0.625624        1.000000
# Electricity(kWh)                                0.921889        0.462020
# Electricity(kBtu)                               0.921889        0.462020
# NaturalGas(therms)                              0.589688        0.076905
# NaturalGas(kBtu)                                0.589688        0.076905
# OtherFuelUse(kBtu)                              0.006961       -0.001926
# GHGEmissions(MetricTonsCO2e)                    0.888859        0.813118
# GHGEmissionsIntensity(kgCO2e/ft2)               0.315751        0.259311
#
#                                    Electricity(kWh)  Electricity(kBtu)  \
# YearBuilt                                  0.101451           0.101451
# NumberofBuildings                          0.062270           0.062270
# NumberofFloors                             0.453377           0.453377
# PropertyGFATotal                           0.690124           0.690124
# PropertyGFAParking                         0.370977           0.370977
# PropertyGFABuilding(s)                     0.705652           0.705652
# ENERGYSTARScore                           -0.064924          -0.064924
# SiteEUI(kBtu/sf)                           0.460232           0.460232
# SiteEUIWN(kBtu/sf)                         0.430456           0.430456
# SourceEUI(kBtu/sf)                         0.523104           0.523104
# SourceEUIWN(kBtu/sf)                       0.507121           0.507121
# SiteEnergyUse(kBtu)                        0.938876           0.938876
# SiteEnergyUseWN(kBtu)                      0.921889           0.921889
# SteamUse(kBtu)                             0.462020           0.462020
# Electricity(kWh)                           1.000000           1.000000
# Electricity(kBtu)                          1.000000           1.000000
# NaturalGas(therms)                         0.373456           0.373456
# NaturalGas(kBtu)                           0.373456           0.373456
# OtherFuelUse(kBtu)                         0.066848           0.066848
# GHGEmissions(MetricTonsCO2e)               0.675881           0.675881
# GHGEmissionsIntensity(kgCO2e/ft2)          0.157292           0.157292
#
#                                    NaturalGas(therms)  NaturalGas(kBtu)  \
# YearBuilt                                    0.013552          0.013553
# NumberofBuildings                           -0.007307         -0.007307
# NumberofFloors                               0.129906          0.129906
# PropertyGFATotal                             0.325736          0.325736
# PropertyGFAParking                           0.093083          0.093082
# PropertyGFABuilding(s)                       0.355549          0.355549
# ENERGYSTARScore                             -0.112974         -0.112974
# SiteEUI(kBtu/sf)                             0.329646          0.329646
# SiteEUIWN(kBtu/sf)                           0.333866          0.333866
# SourceEUI(kBtu/sf)                           0.217131          0.217131
# SourceEUIWN(kBtu/sf)                         0.215894          0.215894
# SiteEnergyUse(kBtu)                          0.577328          0.577328
# SiteEnergyUseWN(kBtu)                        0.589688          0.589688
# SteamUse(kBtu)                               0.076905          0.076905
# Electricity(kWh)                             0.373456          0.373456
# Electricity(kBtu)                            0.373456          0.373456
# NaturalGas(therms)                           1.000000          1.000000
# NaturalGas(kBtu)                             1.000000          1.000000
# OtherFuelUse(kBtu)                          -0.008191         -0.008191
# GHGEmissions(MetricTonsCO2e)                 0.627828          0.627828
# GHGEmissionsIntensity(kgCO2e/ft2)            0.414326          0.414326
#
#                                    OtherFuelUse(kBtu)  \
# YearBuilt                                   -0.023860
# NumberofBuildings                           -0.001279
# NumberofFloors                               0.080306
# PropertyGFATotal                             0.123384
# PropertyGFAParking                           0.063256
# PropertyGFABuilding(s)                       0.127002
# ENERGYSTARScore                              0.023550
# SiteEUI(kBtu/sf)                            -0.000470
# SiteEUIWN(kBtu/sf)                          -0.016209
# SourceEUI(kBtu/sf)                           0.004664
# SourceEUIWN(kBtu/sf)                        -0.011614
# SiteEnergyUse(kBtu)                          0.048241
# SiteEnergyUseWN(kBtu)                        0.006961
# SteamUse(kBtu)                              -0.001926
# Electricity(kWh)                             0.066848
# Electricity(kBtu)                            0.066848
# NaturalGas(therms)                          -0.008191
# NaturalGas(kBtu)                            -0.008191
# OtherFuelUse(kBtu)                           1.000000
# GHGEmissions(MetricTonsCO2e)                 0.005196
# GHGEmissionsIntensity(kgCO2e/ft2)           -0.015985
#
#                                    GHGEmissions(MetricTonsCO2e)  \
# YearBuilt                                              0.022794
# NumberofBuildings                                      0.004351
# NumberofFloors                                         0.207579
# PropertyGFATotal                                       0.492319
# PropertyGFAParking                                     0.120687
# PropertyGFABuilding(s)                                 0.542862
# ENERGYSTARScore                                       -0.097878
# SiteEUI(kBtu/sf)                                       0.351278
# SiteEUIWN(kBtu/sf)                                     0.345217
# SourceEUI(kBtu/sf)                                     0.278173
# SourceEUIWN(kBtu/sf)                                   0.272832
# SiteEnergyUse(kBtu)                                    0.882793
# SiteEnergyUseWN(kBtu)                                  0.888859
# SteamUse(kBtu)                                         0.813118
# Electricity(kWh)                                       0.675881
# Electricity(kBtu)                                      0.675881
# NaturalGas(therms)                                     0.627828
# NaturalGas(kBtu)                                       0.627828
# OtherFuelUse(kBtu)                                     0.005196
# GHGEmissions(MetricTonsCO2e)                           1.000000
# GHGEmissionsIntensity(kgCO2e/ft2)                      0.419585
#
#                                    GHGEmissionsIntensity(kgCO2e/ft2)
# YearBuilt                                                  -0.194266
# NumberofBuildings                                          -0.012798
# NumberofFloors                                             -0.005582
# PropertyGFATotal                                            0.038034
# PropertyGFAParking                                         -0.070136
# PropertyGFABuilding(s)                                      0.063721
# ENERGYSTARScore                                            -0.261099
# SiteEUI(kBtu/sf)                                            0.667590
# SiteEUIWN(kBtu/sf)                                          0.698495
# SourceEUI(kBtu/sf)                                          0.417951
# SourceEUIWN(kBtu/sf)                                        0.429871
# SiteEnergyUse(kBtu)                                         0.303591
# SiteEnergyUseWN(kBtu)                                       0.315751
# SteamUse(kBtu)                                              0.259311
# Electricity(kWh)                                            0.157292
# Electricity(kBtu)                                           0.157292
# NaturalGas(therms)                                          0.414326
# NaturalGas(kBtu)                                            0.414326
# OtherFuelUse(kBtu)                                         -0.015985
# GHGEmissions(MetricTonsCO2e)                                0.419585
# GHGEmissionsIntensity(kgCO2e/ft2)                           1.000000
#
# [21 rows x 21 columns]

# %%
def diagnostic_plots(df, variable):
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
def second(x):
  data1[x+'exp']=data1[x] **(1/5)
  diagnostic_plots(data1,x+'exp')
def first(x):
  data[x+'exp']=data[x] **(1/5)
  diagnostic_plots(data,x+'exp')

# %%
first('NaturalGas(therms)')

# %%
first('GHGEmissions(MetricTonsCO2e)')
first('Electricity(kWh)')
first('SiteEnergyUse(kBtu)')
first('SiteEUI(kBtu/sf)')

# %%
second('GHGEmissions(MetricTonsCO2e)')
second('Electricity(kWh)')
second('SiteEnergyUse(kBtu)')
second('SiteEUI(kBtu/sf)')
# Out:
# C:\Users\SAMARTH P SHET\Downloads\New folder\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\SAMARTH P SHET\Downloads\New folder\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %% [markdown]
# ## to reduce the skewness,we need to exponential

# %%
(data['SiteEnergyUse(kBtu)']).corr(data['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.8827934971603135

# %%
(data['SiteEnergyUse(kBtu)exp']).corr(data['GHGEmissions(MetricTonsCO2e)exp'])
# Out:
# 0.8927669071634424

# %%
(data['Electricity(kWh)']).corr(data['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.675881204141581

# %%
(data['Electricity(kWh)exp']).corr(data['GHGEmissions(MetricTonsCO2e)exp'])
# Out:
# 0.6774135106100931

# %%
(data['SiteEUI(kBtu/sf)']).corr(data['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.35127839364204994

# %%
(data['SiteEUI(kBtu/sf)exp']).corr(data['GHGEmissions(MetricTonsCO2e)exp'])
# Out:
# 0.6772795268582353

# %%
import numpy as np
import seaborn as sns

# %% [markdown]
# # Plotting hist plot for the 2015 data for features used for traning

# %%
viz = data[['Electricity(kWh)exp','SiteEnergyUse(kBtu)exp','GHGEmissions(MetricTonsCO2e)exp','SiteEUI(kBtu/sf)exp']]
viz.hist(figsize=(12,7))
plt.show()

# %%
viz1 = data1[['Electricity(kWh)exp','SiteEnergyUse(kBtu)exp','GHGEmissions(MetricTonsCO2e)exp','SiteEUI(kBtu/sf)exp']]
viz1.hist(figsize=(12,7))
plt.show()

# %%
def plot2015(x):
  sns.scatterplot(x=x ,y='GHGEmissions(MetricTonsCO2e)exp' ,data=data).set_title('Scatter plot 2015')
def plot2016(x):
  sns.scatterplot(x=x ,y='GHGEmissions(MetricTonsCO2e)exp' ,data=data1).set_title('Scatter plot 2016')

# %%
plot2015('Electricity(kWh)exp')

# %%
plot2015('SiteEnergyUse(kBtu)exp')

# %%
plot2015('SiteEUI(kBtu/sf)exp')

# %%
plot2016('Electricity(kWh)exp')

# %%
plot2016('SiteEnergyUse(kBtu)exp')

# %%
plot2016('SiteEUI(kBtu/sf)exp')

# %%
from sklearn.model_selection import train_test_split
X = viz[['Electricity(kWh)exp','SiteEnergyUse(kBtu)exp','SiteEUI(kBtu/sf)exp']]
y= viz['GHGEmissions(MetricTonsCO2e)exp']
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=1)
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit (X_train, y_train)
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
Yhat =regr.predict(X_test[['Electricity(kWh)exp','SiteEnergyUse(kBtu)exp','SiteEUI(kBtu/sf)exp']])
y_test = np.asanyarray(y_test)
print("test data score",regr.score(X_test,y_test))
print("train data score",regr.score(X_train,y_train))
from sklearn.metrics import r2_score
print("Mean absolute error: %.2f" % np.mean(np.absolute(Yhat - y_test)))
print("Residual sum of squares (MSE): %.2f" % np.mean((Yhat - y_test) ** 2))
print("R2-score: %.2f" % r2_score(Yhat ,y_test) )
# Out:
# Coefficients:  [-0.20504463  0.26662627  0.00350006]
# Intercept:  -0.1559471162815762
# test data score 0.9672844690679052
# train data score 0.965531974125993
# Mean absolute error: 0.10
# Residual sum of squares (MSE): 0.01
# R2-score: 0.97

# %% [markdown]
# # Coefficients: [-0.15004845 0.22623525 0.02735087]

# %% [markdown]
# # Intercept: -0.15594711628157576

# %% [markdown]
# # test data score 0.9672844690679052

# %% [markdown]
# # train data score 0.9655319741259931

# %% [markdown]
# # Mean absolute error: 0.10

# %% [markdown]
# # Residual sum of squares (MSE): 0.01

# %% [markdown]
# # R2-score: 0.97

# %%
#x_train = np.asanyarray(X_train[['Electricity(kWh)exp','SiteEnergyUse(kBtu)exp','SiteEUI(kBtu/sf)exp']])
#y_train = np.asanyarray(y_train)

# %%
#x_train= x_train.reshape(-1, 1)
#y_train= y_train.reshape(-1, 1)

# %%
#x_test= np.asanyarray(X_test[['Electricity(kWh)exp','SiteEnergyUse(kBtu)exp','SiteEUI(kBtu/sf)exp']])
#y_test = np.asanyarray(y_test)
#x_test= x_test.reshape(-1, 1)
#y_test= y_test.reshape(-1, 1)

# %% [markdown]
# # Coefficients: [-0.15004845 0.22623525 0.02735087]

# %% [markdown]
# # Intercept: -0.20394611301305066

# %% [markdown]
# # test score 0.9460785847641238

# %% [markdown]
# # train score 0.8929097327887698

# %% [markdown]
# # Mean absolute error: 0.12

# %% [markdown]
# # Residual sum of squares (MSE): 0.02

# %% [markdown]
# # R2-score: 0.94

# %% [markdown]
# # Using the 2016 data set to test acuracy of 2015 regrestion model

# %%
regr.score(X_test16,y_test16)
# Out:
# 0.9606906171089563

# %%
from sklearn.model_selection import cross_val_score
scores15 = cross_val_score(regr, X, y, cv=10)
print("scores",scores15)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores15.mean(), scores15.std()))
# Out:
# scores [0.94066301 0.94677872 0.96360304 0.96178267 0.96172394 0.96618696
#  0.95464987 0.95965088 0.96156071 0.96488887]
# 0.96 accuracy with a standard deviation of 0.01

# %%
sns.scatterplot(x='ENERGYSTARScore' ,y='GHGEmissions(MetricTonsCO2e)' ,data=data)

# %%
data['ENERGYSTARScore']
# Out:
# OSEBuildingID
# 1        65.0
# 2        51.0
# 3        18.0
# 5         1.0
# 8        67.0
#          ...
# 50049    71.0
# 50055    98.0
# 50057    79.0
# 50058    44.0
# 50059    24.0
# Name: ENERGYSTARScore, Length: 2557, dtype: float64

# %%
sns.scatterplot(x='ENERGYSTARScore' ,y='GHGEmissions(MetricTonsCO2e)exp' ,data=data)
